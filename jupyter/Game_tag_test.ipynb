# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
game_tag = pd.read_csv('data/steamspy_tag_data.csv', sep=",", encoding='utf-8', low_memory=False)

# %%
game_tag.columns
# Out:
# Index(['appid', '1980s', '1990s', '2.5d', '2d', '2d_fighter', '360_video',
#        '3d', '3d_platformer', '3d_vision',
#        ...
#        'warhammer_40k', 'web_publishing', 'werewolves', 'western', 'word_game',
#        'world_war_i', 'world_war_ii', 'wrestling', 'zombies', 'e_sports'],
#       dtype='object', length=372)

# %%
def get_max_tag(df):
    result = []
    for index, row in df.iterrows():
        appid = row['appid']
        tags = row.drop('appid')
        max_tag = tags.idxmax()
        result.append({'appid':appid,'main_tag':max_tag})
    return pd.DataFrame(result)
main_game_tag = get_max_tag(game_tag)

# %%
# Out:
#     appid      main_tag
# 0      10        action
# 1      20        action
# 2      30           fps
# 3      40        action
# 4      50           fps
# 5      60        action
# 6      70           fps
# 7      80        action
# 8     130           fps
# 9     220           fps
# 10    240        action
# 11    280           fps
# 12    300           fps
# 13    320        action
# 14    340           fps
# 15    360        action
# 16    380           fps
# 17    400        puzzle
# 18    420           fps
# 19    440  free_to_play
# 20    500       zombies
# 21    550       zombies
# 22    570  free_to_play
# 23    620        puzzle
# 24    630  free_to_play
# 25    730           fps
# 26   1002         indie
# 27   1200  world_war_ii
# 28   1250           fps
# 29   1300        action

# %%
main_game_tag[main_game_tag['main_tag']=='dark_fantasy']
# Out:
#         appid      main_tag
# 6272   374320  dark_fantasy
# 13435  570940  dark_fantasy
